# %% [markdown]
# <a href="https://colab.research.google.com/github/HareshHKkrishna/Skin_disease_diagonizer/blob/main/Lumous.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tensorflow.keras.utils import get_file
from sklearn.metrics import roc_curve, auc, confusion_matrix
from imblearn.metrics import sensitivity_score, specificity_score

import os
import glob
import zipfile
import random

tf.random.set_seed(7)
np.random.seed(7)
random.seed(7)

class_names = ["Low-risk", "High-risk"]

# %%
def download_and_extract_dataset():
  train_url = "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip"
  valid_url = "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip"
  test_url  = "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip"
  for i, download_link in enumerate([valid_url, train_url, test_url]):
    temp_file = f"temp{i}.zip"
    data_dir = get_file(origin=download_link, fname=os.path.join(os.getcwd(), temp_file))
    print("Extracting", download_link)
    with zipfile.ZipFile(data_dir, "r") as z:
      z.extractall("data")
    os.remove(temp_file)
download_and_extract_dataset()
# Out:
# Downloading data from https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip
# 864538487/864538487 [==============================] - 53s 0us/step
# Extracting https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip
# Downloading data from https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip
# 5736557430/5736557430 [==============================] - 348s 0us/step
# Extracting https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip
# Downloading data from https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip
# 5528640507/5528640507 [==============================] - 332s 0us/step
# Extracting https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip

# %%
def generate_csv(folder, label2int):
    folder_name = os.path.basename(folder)
    labels = list(label2int)
    df = pd.DataFrame(columns=["filepath", "label"])
    i = 0
    for label in labels:
        print("Reading", os.path.join(folder, label, "*"))
        for filepath in glob.glob(os.path.join(folder, label, "*")):
            df.loc[i] = [filepath, label2int[label]]
            i += 1
    output_file = f"{folder_name}.csv"
    print("Saving", output_file)
    df.to_csv(output_file)
generate_csv("data/train", {"nevus": 0, "seborrheic_keratosis": 0, "melanoma": 1})
generate_csv("data/valid", {"nevus": 0, "seborrheic_keratosis": 0, "melanoma": 1})
generate_csv("data/test", {"nevus": 0, "seborrheic_keratosis": 0, "melanoma": 1})
# Out:
# Reading data/train/nevus/*
# Reading data/train/seborrheic_keratosis/*
# Reading data/train/melanoma/*
# Saving train.csv
# Reading data/valid/nevus/*
# Reading data/valid/seborrheic_keratosis/*
# Reading data/valid/melanoma/*
# Saving valid.csv
# Reading data/test/nevus/*
# Reading data/test/seborrheic_keratosis/*
# Reading data/test/melanoma/*
# Saving test.csv

# %%
train_metadata_filename = "train.csv"
valid_metadata_filename = "valid.csv"
df_train = pd.read_csv(train_metadata_filename)
df_valid = pd.read_csv(valid_metadata_filename)
n_training_samples = len(df_train)
n_validation_samples = len(df_valid)
print("Number of training samples:", n_training_samples)
print("Number of validation samples:", n_validation_samples)
train_ds = tf.data.Dataset.from_tensor_slices((df_train["filepath"], df_train["label"]))
valid_ds = tf.data.Dataset.from_tensor_slices((df_valid["filepath"], df_valid["label"]))
# Out:
# Number of training samples: 2000
# Number of validation samples: 150

# %%
def decode_img(img):
  img = tf.image.decode_jpeg(img, channels=3)
  img = tf.image.convert_image_dtype(img, tf.float32)
  return tf.image.resize(img, [299, 299])


def process_path(filepath, label):
  img = tf.io.read_file(filepath)
  img = decode_img(img)
  return img, label


valid_ds = valid_ds.map(process_path)
train_ds = train_ds.map(process_path)
for image, label in train_ds.take(1):
    print("Image shape:", image.shape)
    print("Label:", label.numpy())
# Out:
# Image shape: (299, 299, 3)
# Label: 0

# %%
batch_size = 64
optimizer = "rmsprop"

def prepare_for_training(ds, cache=True, batch_size=64, shuffle_buffer_size=1000):
  if cache:
    if isinstance(cache, str):
      ds = ds.cache(cache)
    else:
      ds = ds.cache()
  ds = ds.shuffle(buffer_size=shuffle_buffer_size)
  ds = ds.repeat()
  ds = ds.batch(batch_size)
  ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
  return ds

valid_ds = prepare_for_training(valid_ds, batch_size=batch_size, cache="valid-cached-data")
train_ds = prepare_for_training(train_ds, batch_size=batch_size, cache="train-cached-data")

# %%
batch = next(iter(valid_ds))

def show_batch(batch):
  plt.figure(figsize=(12,12))
  for n in range(25):
      ax = plt.subplot(5,5,n+1)
      plt.imshow(batch[0][n])
      plt.title(class_names[batch[1][n].numpy()].title())
      plt.axis('off')
        
show_batch(batch)

# %%
module_url = "https://tfhub.dev/google/tf2-preview/inception_v3/feature_vector/4"
m = tf.keras.Sequential([
    hub.KerasLayer(module_url, output_shape=[2048], trainable=False),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

m.build([None, 299, 299, 3])
m.compile(loss="binary_crossentropy", optimizer=optimizer, metrics=["accuracy"])
m.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 2048)              21802784
#
#  dense (Dense)               (None, 1)                 2049
#
# =================================================================
# Total params: 21,804,833
# Trainable params: 2,049
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
model_name = f"benign-vs-malignant_{batch_size}_{optimizer}"
tensorboard = tf.keras.callbacks.TensorBoard(log_dir=os.path.join("logs", model_name))

modelcheckpoint = tf.keras.callbacks.ModelCheckpoint(model_name + "_{val_loss:.3f}.h5", save_best_only=True, verbose=1)

history = m.fit(train_ds, validation_data=valid_ds, 
                steps_per_epoch=n_training_samples // batch_size, 
                validation_steps=n_validation_samples // batch_size, verbose=1, epochs=50,
                callbacks=[tensorboard, modelcheckpoint])
# Out:
# Epoch 1/50
# 31/31 [==============================] - ETA: 0s - loss: 0.4109 - accuracy: 0.8110
# Epoch 1: val_loss improved from inf to 0.50973, saving model to benign-vs-malignant_64_rmsprop_0.510.h5
# 31/31 [==============================] - 275s 5s/step - loss: 0.4109 - accuracy: 0.8110 - val_loss: 0.5097 - val_accuracy: 0.7969
# Epoch 2/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3949 - accuracy: 0.8170
# Epoch 2: val_loss improved from 0.50973 to 0.47206, saving model to benign-vs-malignant_64_rmsprop_0.472.h5
# 31/31 [==============================] - 17s 562ms/step - loss: 0.3949 - accuracy: 0.8170 - val_loss: 0.4721 - val_accuracy: 0.8047
# Epoch 3/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3789 - accuracy: 0.8180
# Epoch 3: val_loss improved from 0.47206 to 0.44998, saving model to benign-vs-malignant_64_rmsprop_0.450.h5
# 31/31 [==============================] - 12s 401ms/step - loss: 0.3789 - accuracy: 0.8180 - val_loss: 0.4500 - val_accuracy: 0.8125
# Epoch 4/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3645 - accuracy: 0.8291
# Epoch 4: val_loss did not improve from 0.44998
# 31/31 [==============================] - 9s 300ms/step - loss: 0.3645 - accuracy: 0.8291 - val_loss: 0.4822 - val_accuracy: 0.7812
# Epoch 5/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3460 - accuracy: 0.8488
# Epoch 5: val_loss improved from 0.44998 to 0.44856, saving model to benign-vs-malignant_64_rmsprop_0.449.h5
# 31/31 [==============================] - 9s 305ms/step - loss: 0.3460 - accuracy: 0.8488 - val_loss: 0.4486 - val_accuracy: 0.8125
# Epoch 6/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3464 - accuracy: 0.8498
# Epoch 6: val_loss did not improve from 0.44856
# 31/31 [==============================] - 9s 296ms/step - loss: 0.3464 - accuracy: 0.8498 - val_loss: 0.4541 - val_accuracy: 0.7812
# Epoch 7/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3434 - accuracy: 0.8397
# Epoch 7: val_loss did not improve from 0.44856
# 31/31 [==============================] - 9s 291ms/step - loss: 0.3434 - accuracy: 0.8397 - val_loss: 0.4736 - val_accuracy: 0.7578
# Epoch 8/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3355 - accuracy: 0.8508
# Epoch 8: val_loss improved from 0.44856 to 0.41556, saving model to benign-vs-malignant_64_rmsprop_0.416.h5
# 31/31 [==============================] - 9s 296ms/step - loss: 0.3355 - accuracy: 0.8508 - val_loss: 0.4156 - val_accuracy: 0.8125
# Epoch 9/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3412 - accuracy: 0.8503
# Epoch 9: val_loss improved from 0.41556 to 0.41327, saving model to benign-vs-malignant_64_rmsprop_0.413.h5
# 31/31 [==============================] - 9s 302ms/step - loss: 0.3412 - accuracy: 0.8503 - val_loss: 0.4133 - val_accuracy: 0.8281
# Epoch 10/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3138 - accuracy: 0.8584
# Epoch 10: val_loss did not improve from 0.41327
# 31/31 [==============================] - 9s 289ms/step - loss: 0.3138 - accuracy: 0.8584 - val_loss: 0.4726 - val_accuracy: 0.7656
# Epoch 11/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3267 - accuracy: 0.8579
# Epoch 11: val_loss did not improve from 0.41327
# 31/31 [==============================] - 9s 289ms/step - loss: 0.3267 - accuracy: 0.8579 - val_loss: 0.4485 - val_accuracy: 0.8047
# Epoch 12/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3205 - accuracy: 0.8589
# Epoch 12: val_loss did not improve from 0.41327
# 31/31 [==============================] - 9s 293ms/step - loss: 0.3205 - accuracy: 0.8589 - val_loss: 0.4318 - val_accuracy: 0.8203
# Epoch 13/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3446 - accuracy: 0.8377
# Epoch 13: val_loss did not improve from 0.41327
# 31/31 [==============================] - 9s 301ms/step - loss: 0.3446 - accuracy: 0.8377 - val_loss: 0.4403 - val_accuracy: 0.8047
# Epoch 14/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3033 - accuracy: 0.8609
# Epoch 14: val_loss did not improve from 0.41327
# 31/31 [==============================] - 9s 280ms/step - loss: 0.3033 - accuracy: 0.8609 - val_loss: 0.4925 - val_accuracy: 0.7500
# Epoch 15/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3199 - accuracy: 0.8569
# Epoch 15: val_loss did not improve from 0.41327
# 31/31 [==============================] - 9s 280ms/step - loss: 0.3199 - accuracy: 0.8569 - val_loss: 0.4168 - val_accuracy: 0.8125
# Epoch 16/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3052 - accuracy: 0.8730
# Epoch 16: val_loss did not improve from 0.41327
# 31/31 [==============================] - 9s 282ms/step - loss: 0.3052 - accuracy: 0.8730 - val_loss: 0.4187 - val_accuracy: 0.7891
# Epoch 17/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3193 - accuracy: 0.8639
# Epoch 17: val_loss did not improve from 0.41327
# 31/31 [==============================] - 9s 290ms/step - loss: 0.3193 - accuracy: 0.8639 - val_loss: 0.4217 - val_accuracy: 0.8125
# Epoch 18/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3075 - accuracy: 0.8659
# Epoch 18: val_loss did not improve from 0.41327
# 31/31 [==============================] - 9s 287ms/step - loss: 0.3075 - accuracy: 0.8659 - val_loss: 0.5132 - val_accuracy: 0.7109
# Epoch 19/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3078 - accuracy: 0.8659
# Epoch 19: val_loss did not improve from 0.41327
# 31/31 [==============================] - 9s 279ms/step - loss: 0.3078 - accuracy: 0.8659 - val_loss: 0.4409 - val_accuracy: 0.8047
# Epoch 20/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3145 - accuracy: 0.8574
# Epoch 20: val_loss did not improve from 0.41327
# 31/31 [==============================] - 9s 296ms/step - loss: 0.3145 - accuracy: 0.8574 - val_loss: 0.4452 - val_accuracy: 0.7969
# Epoch 21/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3044 - accuracy: 0.8715
# Epoch 21: val_loss improved from 0.41327 to 0.41209, saving model to benign-vs-malignant_64_rmsprop_0.412.h5
# 31/31 [==============================] - 10s 309ms/step - loss: 0.3044 - accuracy: 0.8715 - val_loss: 0.4121 - val_accuracy: 0.8203
# Epoch 22/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2902 - accuracy: 0.8684
# Epoch 22: val_loss improved from 0.41209 to 0.41167, saving model to benign-vs-malignant_64_rmsprop_0.412.h5
# 31/31 [==============================] - 10s 325ms/step - loss: 0.2902 - accuracy: 0.8684 - val_loss: 0.4117 - val_accuracy: 0.8125
# Epoch 23/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3137 - accuracy: 0.8669
# Epoch 23: val_loss did not improve from 0.41167
# 31/31 [==============================] - 9s 297ms/step - loss: 0.3137 - accuracy: 0.8669 - val_loss: 0.4415 - val_accuracy: 0.8125
# Epoch 24/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2898 - accuracy: 0.8750
# Epoch 24: val_loss did not improve from 0.41167
# 31/31 [==============================] - 9s 296ms/step - loss: 0.2898 - accuracy: 0.8750 - val_loss: 0.4527 - val_accuracy: 0.7891
# Epoch 25/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2915 - accuracy: 0.8695
# Epoch 25: val_loss did not improve from 0.41167
# 31/31 [==============================] - 9s 294ms/step - loss: 0.2915 - accuracy: 0.8695 - val_loss: 0.4467 - val_accuracy: 0.7891
# Epoch 26/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2865 - accuracy: 0.8745
# Epoch 26: val_loss did not improve from 0.41167
# 31/31 [==============================] - 9s 299ms/step - loss: 0.2865 - accuracy: 0.8745 - val_loss: 0.4364 - val_accuracy: 0.8125
# Epoch 27/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2918 - accuracy: 0.8775
# Epoch 27: val_loss did not improve from 0.41167
# 31/31 [==============================] - 9s 279ms/step - loss: 0.2918 - accuracy: 0.8775 - val_loss: 0.4382 - val_accuracy: 0.7969
# Epoch 28/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2761 - accuracy: 0.8765
# Epoch 28: val_loss did not improve from 0.41167
# 31/31 [==============================] - 9s 296ms/step - loss: 0.2761 - accuracy: 0.8765 - val_loss: 0.4413 - val_accuracy: 0.8047
# Epoch 29/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3089 - accuracy: 0.8634
# Epoch 29: val_loss improved from 0.41167 to 0.40803, saving model to benign-vs-malignant_64_rmsprop_0.408.h5
# 31/31 [==============================] - 9s 307ms/step - loss: 0.3089 - accuracy: 0.8634 - val_loss: 0.4080 - val_accuracy: 0.8281
# Epoch 30/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2824 - accuracy: 0.8800
# Epoch 30: val_loss did not improve from 0.40803
# 31/31 [==============================] - 9s 295ms/step - loss: 0.2824 - accuracy: 0.8800 - val_loss: 0.4640 - val_accuracy: 0.7578
# Epoch 31/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2935 - accuracy: 0.8730
# Epoch 31: val_loss did not improve from 0.40803
# 31/31 [==============================] - 10s 338ms/step - loss: 0.2935 - accuracy: 0.8730 - val_loss: 0.4497 - val_accuracy: 0.8125
# Epoch 32/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2750 - accuracy: 0.8795
# Epoch 32: val_loss improved from 0.40803 to 0.39729, saving model to benign-vs-malignant_64_rmsprop_0.397.h5
# 31/31 [==============================] - 12s 377ms/step - loss: 0.2750 - accuracy: 0.8795 - val_loss: 0.3973 - val_accuracy: 0.8516
# Epoch 33/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2862 - accuracy: 0.8816
# Epoch 33: val_loss did not improve from 0.39729
# 31/31 [==============================] - 10s 328ms/step - loss: 0.2862 - accuracy: 0.8816 - val_loss: 0.4294 - val_accuracy: 0.8281
# Epoch 34/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2799 - accuracy: 0.8775
# Epoch 34: val_loss did not improve from 0.39729
# 31/31 [==============================] - 20s 650ms/step - loss: 0.2799 - accuracy: 0.8775 - val_loss: 0.4483 - val_accuracy: 0.8125
# Epoch 35/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2804 - accuracy: 0.8881
# Epoch 35: val_loss did not improve from 0.39729
# 31/31 [==============================] - 17s 554ms/step - loss: 0.2804 - accuracy: 0.8881 - val_loss: 0.4386 - val_accuracy: 0.8281
# Epoch 36/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2660 - accuracy: 0.8911
# Epoch 36: val_loss did not improve from 0.39729
# 31/31 [==============================] - 13s 429ms/step - loss: 0.2660 - accuracy: 0.8911 - val_loss: 0.3978 - val_accuracy: 0.8438
# Epoch 37/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2733 - accuracy: 0.8871
# Epoch 37: val_loss did not improve from 0.39729
# 31/31 [==============================] - 15s 505ms/step - loss: 0.2733 - accuracy: 0.8871 - val_loss: 0.4386 - val_accuracy: 0.8203
# Epoch 38/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2688 - accuracy: 0.8886
# Epoch 38: val_loss did not improve from 0.39729
# 31/31 [==============================] - 12s 406ms/step - loss: 0.2688 - accuracy: 0.8886 - val_loss: 0.4901 - val_accuracy: 0.7500
# Epoch 39/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2885 - accuracy: 0.8690
# Epoch 39: val_loss did not improve from 0.39729
# 31/31 [==============================] - 13s 426ms/step - loss: 0.2885 - accuracy: 0.8690 - val_loss: 0.4666 - val_accuracy: 0.7891
# Epoch 40/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2672 - accuracy: 0.8926
# Epoch 40: val_loss did not improve from 0.39729
# 31/31 [==============================] - 16s 541ms/step - loss: 0.2672 - accuracy: 0.8926 - val_loss: 0.4312 - val_accuracy: 0.8359
# Epoch 41/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2628 - accuracy: 0.8901
# Epoch 41: val_loss did not improve from 0.39729
# 31/31 [==============================] - 12s 386ms/step - loss: 0.2628 - accuracy: 0.8901 - val_loss: 0.4525 - val_accuracy: 0.8125
# Epoch 42/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2746 - accuracy: 0.8886
# Epoch 42: val_loss did not improve from 0.39729
# 31/31 [==============================] - 13s 435ms/step - loss: 0.2746 - accuracy: 0.8886 - val_loss: 0.4188 - val_accuracy: 0.8125
# Epoch 43/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2669 - accuracy: 0.8901
# Epoch 43: val_loss did not improve from 0.39729
# 31/31 [==============================] - 14s 457ms/step - loss: 0.2669 - accuracy: 0.8901 - val_loss: 0.4642 - val_accuracy: 0.8047
# Epoch 44/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2720 - accuracy: 0.8826
# Epoch 44: val_loss did not improve from 0.39729
# 31/31 [==============================] - 15s 503ms/step - loss: 0.2720 - accuracy: 0.8826 - val_loss: 0.4367 - val_accuracy: 0.7969
# Epoch 45/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2702 - accuracy: 0.8876
# Epoch 45: val_loss did not improve from 0.39729
# 31/31 [==============================] - 12s 394ms/step - loss: 0.2702 - accuracy: 0.8876 - val_loss: 0.4639 - val_accuracy: 0.7969
# Epoch 46/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2507 - accuracy: 0.8936
# Epoch 46: val_loss did not improve from 0.39729
# 31/31 [==============================] - 15s 484ms/step - loss: 0.2507 - accuracy: 0.8936 - val_loss: 0.4711 - val_accuracy: 0.7969
# Epoch 47/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2809 - accuracy: 0.8780
# Epoch 47: val_loss did not improve from 0.39729
# 31/31 [==============================] - 14s 463ms/step - loss: 0.2809 - accuracy: 0.8780 - val_loss: 0.4454 - val_accuracy: 0.8047
# Epoch 48/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2642 - accuracy: 0.8906
# Epoch 48: val_loss did not improve from 0.39729
# 31/31 [==============================] - 15s 504ms/step - loss: 0.2642 - accuracy: 0.8906 - val_loss: 0.4377 - val_accuracy: 0.8203
# Epoch 49/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2615 - accuracy: 0.8891
# Epoch 49: val_loss did not improve from 0.39729
# 31/31 [==============================] - 15s 477ms/step - loss: 0.2615 - accuracy: 0.8891 - val_loss: 0.4067 - val_accuracy: 0.8359
# Epoch 50/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2525 - accuracy: 0.9002
# Epoch 50: val_loss did not improve from 0.39729
# 31/31 [==============================] - 15s 507ms/step - loss: 0.2525 - accuracy: 0.9002 - val_loss: 0.4340 - val_accuracy: 0.7969

# %%
m.save("Keras_model.h5")
